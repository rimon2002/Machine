# %%
input('Enter your name')
# Out:
# '65'

# %%
name = input('Enter your name:')

# %%
print(name)
# Out:
# 65

# %%
num = int(num)

# %%
type(num)
# Out:
# int

# %%
# array cut[start:end+1]
arr = [56, 7, 8, 76, 8, 6, 8, 4, 8, 3]

# %%
arr[3:9+1]
# Out:
# [76, 8, 6, 8, 4, 8, 3]

# %%
nums = [1, 2, 3, 4, 5, 6, 7, 8]
nums2 = []

for num in nums:
    double = num*2
    nums2.append(double)

# %%
nums = [1, 2, 3, 4, 5, 6, 7]
nums2 = []

for num in nums:
    num = nums*2
    nums2.append(double)

# %%
nums3 = [num*3 for num in nums]

# %%
nums3
# Out:
# [3, 6, 9, 12, 15, 18, 21]

# %%
matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
matrix[1], [2]

# %%
for lst in matrix:
    print(lst)

    for i in lst:
        print(i)
# Out:
# [1, 2, 3]
# 1
# 2
# 3
# [4, 5, 6]
# 4
# 5
# 6
# [7, 8, 9]
# 7
# 8
# 9

# %%
def func (name):
    print(name)

# %%
func('Maybe')
# Out:
# Maybe
